# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from pxsim.generate import generate_arrivals
import matplotlib.pyplot as plt

vals = []
for x in generate_arrivals(11, 1, 1, 3300):
    vals.append(x[0])
plt.plot(vals)
