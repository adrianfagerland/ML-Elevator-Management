# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from pxsim.generate import generate_weeks
import matplotlib.pyplot as plt

generator = generate_weeks(num_weeks=1)
vals = []
for x in generator:
    vals.append(x[0])
plt.plot(vals[:850])
